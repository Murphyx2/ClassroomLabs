# %%
Practice 2

# %% [raw]
# <p style="font-family: Arial; font-size:3em;color:black;"> Session 2 </p>

# %%
# Exploring mean, median and mod in numpy/scipy 

import numpy as np
from scipy import stats

# some sample data for SW engineer salary
SWE_salaries = np.random.normal(100000, 15000, 10000)
print("Mean (average) salary of a SW engineer is:", np.mean(SWE_salaries), "CAD")
# Out:
# Mean (average) salary of a SW engineer is: 100017.02955889305 CAD

# %%
# visualizing the data
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(SWE_salaries, 50)
plt.show()

# %%
# computing the median
print("Median salary of a SW engineer is:", np.median(SWE_salaries), "CAD")
# Out:
# Median salary of a SW engineer is: 99995.56068617833 CAD

# %%
# let's add an outlier, a person making 1 B $/yr
SWE_salaries_w_outlier = np.append(SWE_salaries, [1000000000])

# %%
# Examining mean and median with the above outlier
print("With the outlier, mean (average) salary of a SW engineer is:", np.mean(SWE_salaries_w_outlier), "CAD")
print("With the outlier, , median salary of a SW engineer is:", np.median(SWE_salaries_w_outlier),"CAD")
# Out:
# With the outlier, mean (average) salary of a SW engineer is: 199997.02985590746 CAD
# With the outlier, , median salary of a SW engineer is: 99996.07587813011 CAD

# %%
# in order to explore mod, let's generate some dataset on book pages
no_pages = np.random.randint(50, high=700, size=1000)
print(no_pages)
# Out:
# [591 251 616 109 324  77  62 336 258 433 248 286 166 419 366 188 454 366
#  167 592 389 383 213 576 149 595 558 459 535 528 377 483 563 531 213 339
#  549 297 452 220 240 109 452 569 403 150 583 669 230 576 243 267 521 103
#  679 286 178 324 268 403 544 626 265 454 234 600 287 269 678 503 433 506
#  487  65 401 478 251 123  76  89 415 370 147 444 116 229 662 354 319 608
#  457 604 423 543 671 274  64 145 280 253 332 304 247 698 409 532 439 379
#  312 185 383 527 261 268 566  84 638 673 335 558 665 624 273 567 377 279
#  664 396 234 567 501  91 389 172 447 598 105 563 451 477 665 327 320 226
#  376 469 140 622 130 524 434 496 485 642  95 100 599 257 405 401 203  98
#  564 151 354 144 495 309 519 540 447 586 373 666 425 107  76 653 331 140
#  583 289 401 636 284 276 440  53 274 108 663 403 379 188 641 689 387 293
#  243 605 416 376 347 593 413  89 495 681 212 183 290 457  80 538 678 340
#  376 239 323 514 583 259 529 193 362 301 288 537  87 127 340 625 230 521
#  455 636 224 468 224  92 276  72  86 187 663 105 238 633 698 436 482 321
#  570 527 428 397 564  58 548 182 607 646 201 207 185 534 530 533 409 483
#  353 658 546 301 561  88 304 692 463 569 283 382 587 246 440 518 507 453
#  590 679 222 699 504 643 422 669 648 234 671 468 188 203 242  71 398 161
#  316 334 544 271 317 255 194 229 268 148 570 300 362 186 118 503 680 540
#  359 643 129 200  92 192 125 399 539 650 675 389 396 212 520 137 126 597
#  562 541 528 440 578 585 173 404 257 124 620 503 311 292  71 652 162  56
#  542 250 424 141  75 475 466 495 107 549 243 481 145  80  71 200 519 665
#  365 234  80 340 334 279 262 612 535 256 698 153 511 678 359 642 662 675
#   70 133 233 285 645 513 645 100 485 497 680 278 273 288 490 365 690 585
#  384  97 463 516 111 668  87 468 222 427 112 470 293 232 651 450 106 112
#  241  93 586 153 658 680 459 312 679 646 109 119 121 255 400 421 156 649
#   67 596 130 635 467 352 449 624 536 464 131 543 641 293 339 640 293 494
#  367 380 515 100 138  84 518 169 367 180 378 258 397 238 698 328 494 208
#   85 669 574 181 485 394 401 219 685 375 447 111  80 405 215 567 249 605
#  469 503 185  51 465 108  51 256 424 207 482 424 651  82  92 447 249 653
#  685 658 186 473 553 232 506 234 365 105 630 587 227 248  67 148 144 115
#  640 440  59 228 397 302 470 202 246 399 141 328 254 590 629 427 436 140
#  421 550 487 366 574 645 425 369 549 400 471  99  99 404 628 306 603 595
#  479 384 133 399 464 125  70 388 442 565  64 223 518 687  65 410 646 684
#  335 225  94 340 170 615 673 668 371 388 644 603 246  79 249 106 351 503
#  456 663 592  88 139 107 109  61 114 263 592 549 135 102 657  84 470 141
#  501 217 189 241 311 672  94 296 617 319 264 472 243  66 360 139 547 373
#  430 561 451 558 537 320 588 573 540 317 160 442 591  88 300 185  69 672
#  684 379  94 212 440 490 187 193 490 510  69 175 182 386 655 487 222 475
#  451 533 413 216 263 153 278 160 420 470 374 465 335 140 261 402 596 461
#   98 598 138 672 641  88 526 238 409 141 145 164 341  61 418 681 332 440
#  503 269  96 378 152 398 237 385 648 105 351 398 482 523 182 193 461 243
#  439 530 395 550 323 490 481 472  99 463 577 238 414 230  54 276 210 360
#  127 130 222 428 294 122 112 275 403 587 541 455 265  94 123 252 554 484
#  138 307 137 693  88 149 551  90 406 337 143 409 140 430 394 413  50 606
#  252  73 433 580 680 200 207 380 100 253 393 639 603 350 472 648 593 492
#  265 325 356 668 155 426 325 466 599 643 351 548  65 556 390 664 503 502
#  124 415 141 319 431 333 349 241 644 332 267 579 145 580 601 323 183 665
#  202 147 244 498 283 325 243  93 324 338 161 424 691 239 170 201 413 218
#  545 338 301 132  56 432 422 547 326 205 447 379 584 279  69 360 323 520
#  411 531 539 247 426 482 400 274 132 578 103  99  77 375 390 131 509 404
#  209  87 316 652 650 602 100  95 117 583 209  90 456 542 677 682 634 336
#  490 402 222 632  52 505 244 314 176 521 108 577 499 616 597 662 521 575
#  132 482 600 313 658 403  86 198 682 635 106 477 468 226 200  51 533 195
#  134 504 241 343 569 106 488 379 383 565 690 124 194 619 658  87  62 186
#  625 242 380 423 612  95 435  52 336 163 561 104 129 242 214 115 166  88
#  463 567 646 693 202 460 153 274 158  97]

# %%
stats.mode(no_pages)
# Out:
# ModeResult(mode=array([503]), count=array([7]))

# %%
# uniform distribution
uniform_values = np.random.uniform(-10.0, 10.0, 100000)
plt.hist(uniform_values, 50)
plt.show()

# %%
# normal distribution
from scipy.stats import norm

x = np.arange(-3, 3, 0.001)   # Returns evenly spaced values within the interval
plt.plot(x,norm.pdf(x))       # pdf is continuous vs. relative frequency histogram
plt.show()

normal_values = np.random.normal(0, 1, 6000)  # for the above pdf: 6 x Std = 3+3 ==> Std=1
plt.hist(normal_values, 50)   # histogram is discrete, dividing the values by the area underneath the histogram returns the relative frequency histogram
plt.show()

# %%
random_values_array = np.random.normal(100, 20, 100000)       # np.random.normal(mean, std, # of elements)
plt.hist(random_values_array, 50)
plt.show()

print(np.percentile(random_values_array, 2.5))
print(np.percentile(random_values_array, 16))
print(np.percentile(random_values_array, 50))
print(np.percentile(random_values_array, 84))
print(np.percentile(random_values_array, 97.5))
# Out:
# 60.95008728108465
# 80.24570718873493
# 100.01627529023779
# 119.9418758493206
# 139.1654379416426

# %%
# linear algebra
first_var = np.array([8,5,4])
sec_var = np.array([0,-2,14])
print(np.dot(first_var,sec_var))
print(np.inner(first_var,sec_var))
print(np.cross(first_var,sec_var))
print(np.dot(first_var,np.cross(first_var,sec_var)))
print(np.dot(sec_var,np.cross(first_var,sec_var)))
# Out:
# 46
# 46
# [  78 -112  -16]
# 0
# 0

# %%
# covariance and correleation
ind_var = np.random.normal(100, 10, 1000)
dep_var = np.random.normal(80, 10, 1000)*0.15*ind_var + 1.4

print("Vaiance of ind_var is:", ind_var.var(),'\n')  # print with line break
print("Vaiance of dep_var is:", dep_var.var(),'\n')
print("Covaiance cov(ind_var,dep_var) is:", np.cov(ind_var,dep_var)[0][1],'\n')
print("Correlation of ind_var an dep_var is:", np.cov(ind_var,dep_var)[0][1]/(ind_var.std()*dep_var.std()),'\n')

plt.plot(ind_var,dep_var,'.')
plt.show()
# Out:
# Vaiance of ind_var is: 101.12911071115337
#
# Vaiance of dep_var is: 38230.42126841755
#
# Covaiance cov(ind_var,dep_var) is: 1242.684848846431
#
# Correlation of ind_var an dep_var is: 0.63200187596758

# %%
from numpy.linalg import inv
from numpy.linalg import det
from numpy.linalg import matrix_rank
from sympy import Matrix

a_mat = np.array([[1., 2.], [3., 4.]])
b_mat = np.array([[2, 1, 0], [0, 2, 0], [2, 0, 1]])
c_mat_linearly_dependent = np.array([[2, 1, 1], [0, 2, -2], [4, 4, 0]])

# %%
print("Determinant of a_mat is:", det(a_mat))
print("Determinant of b_mat is:", det(b_mat))
print("Determinant of c_mat is:", det(c_mat_linearly_dependent))
print("Rank of a_mat is:", matrix_rank(a_mat))
print("Rank of b_mat is:", matrix_rank(b_mat))
print("Rank of c_mat is:", matrix_rank(c_mat_linearly_dependent))
print("reduced row echelon form of a_mat", Matrix(a_mat).rref())
print("reduced row echelon form of b_mat", Matrix(b_mat).rref())
print("reduced row echelon form of c_mat", Matrix(c_mat_linearly_dependent).rref())
print("Inverse of a_mat is:", inv(a_mat))
print("Inverse of b_mat is:", inv(b_mat))
print("b_mat mutiplied by its inverse inv(b_mat) is:", np.matmul(b_mat,inv(b_mat)))        # use np.matmul for matrix multiplication in numpy
# Out:
# Determinant of a_mat is: -2.0000000000000004
# Determinant of b_mat is: 4.0
# Determinant of c_mat is: -3.330669073875464e-16
# Rank of a_mat is: 2
# Rank of b_mat is: 3
# Rank of c_mat is: 2
# reduced row echelon form of a_mat (Matrix([
# [1, 0],
# [0, 1]]), (0, 1))
# reduced row echelon form of b_mat (Matrix([
# [1, 0, 0],
# [0, 1, 0],
# [0, 0, 1]]), (0, 1, 2))
# reduced row echelon form of c_mat (Matrix([
# [1, 0, 3],
# [0, 1, 1],
# [0, 0, 0]]), (0, 1))
# Inverse of a_mat is: [[-2.   1. ]
#  [ 1.5 -0.5]]
# Inverse of b_mat is: [[ 0.5  -0.25  0.  ]
#  [ 0.    0.5   0.  ]
#  [-1.    0.5   1.  ]]
# b_mat mutiplied by its inverse inv(b_mat) is: [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
